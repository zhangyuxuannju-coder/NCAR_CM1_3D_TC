# %% [markdown]
# # SE 方程诊断 — Thompson 方案 (t=72h)
#
# **数据文件**: `cm1out_thompson.nc`
# **时间**: 72 小时 (259200 s)
# **网格**: Δr = 12 km, SOR ω = 1.5, tolerance = 1.5×10⁻⁹
# **边界条件**: 底边界 ψ=0, 顶边界 ∂ψ/∂z=0 (自由滑移)
# **SOR 迭代**: 2266 步收敛, max residual = 1.5×10⁻⁹

# %% [markdown]
# ---
# ## SE 解场: ψ (流函数) / U_se (径向风) / W_se (垂直风)

# %%
from IPython.display import Image, display
display(Image(filename='../output/se_pipeline/thompson/se_solution_fields.png'))

# %% [markdown]
# ---
# ## SE 强迫项: Q, F, A-F 各项

# %%
display(Image(filename='../output/se_pipeline/thompson/se_forcing_terms.png'))

# %% [markdown]
# ---
# ## 数据加载与快速查看

# %%
import xarray as xr
import numpy as np

# 如果有 nc 文件可以直接加载分析
# ds = xr.open_dataset('../output/se_pipeline/thompson/se_pipeline_products.nc')
# ds
